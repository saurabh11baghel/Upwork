# %%
import pandas as pd
import numpy as np
from collections import Counter

# %%
data = pd.read_csv("asn_features.csv")
labels = pd.read_csv("labels.csv")
data
# Out:
#              id                                               name  \
# 0        AS3245                                Digital Systems Ltd
# 1        AS6769                     State Enterprise Infostruktura
# 2        AS8613                            Phoenix IT Services Ltd
# 3        AS9245                         Compass Communications Ltd
# 4       AS14576                              Hosting Solution Ltd.
# 5       AS24637                          WEBDISCOUNT GmbH & Co. KG
# 6       AS57858                                 Inter Connects Inc
# 7       AS59216        JuxtConsult Research & Consulting Pvt. Ltd.
# 8      AS206170                                          Inleed AB
# 9      AS265405            Imax Wireless Provedor de Internet Ltda
# 10      AS26277                            Las Vegas NV Datacenter
# 11       AS9313                      Network Technology (AUST) P/L
# 12      AS11404                                   vanoppen.biz LLC
# ...

# %%
data.isnull().any()
# Out:
# id                  False
# name                 True
# domain               True
# ips                 False
# prefixes            False
# ranges              False
# domains             False
# domain_ips          False
# traffic_ranges      False
# traffic_ips         False
# country_rank        False
# country_traffic     False
# rdns_count          False
# rdns_total          False
# rdns_num_domains    False
# rdns_pct            False
# dtype: bool
